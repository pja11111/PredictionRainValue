# %%
import pandas as pd

# %%
df = pd.read_csv('dsl_dry-wet.csv')
df2 = pd.read_csv('o_th1970-current_thai.csv')
df3 = pd.read_csv('r35mm_dry-wet.csv')
dataset_rain = pd.read_csv('dataset_rain.csv')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df.head()
# Out:
#    ProvinceID Province_Name  Year  DSL (Day)
# 0          10       Bangkok  1979         22
# 1          10       Bangkok  1980          9
# 2          10       Bangkok  1981          9
# 3          10       Bangkok  1982         10
# 4          10       Bangkok  1983         10

# %%
df2.head()
# Out:
#    YEAR  MONTH        MIN         MAX        MEAN
# 0  1970      1   0.000000  387.690002   24.478840
# 1  1970      2   0.000000  165.089996   15.165154
# 2  1970      3   0.000000  198.380005   47.723809
# 3  1970      4   5.010000  273.730011   90.817995
# 4  1970      5  47.200001  510.250000  212.967612

# %%
df2.rename(columns={'YEAR': 'Year'}, inplace=True)

# %%
df3.head()
# Out:
#    ProvinceID Province_Name  Year  R35mm (Day)
# 0          10       Bangkok  1979            6
# 1          10       Bangkok  1980            8
# 2          10       Bangkok  1981            9
# 3          10       Bangkok  1982           10
# 4          10       Bangkok  1983           13

# %%
df4 = df.merge(df3, left_on=['Year','Province_Name','ProvinceID'], right_on=['Year','Province_Name','ProvinceID'], how='left')

# %%
df5 = df4.merge(df2, left_on='Year', right_on='Year', how='left')

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41580 entries, 0 to 41579
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ProvinceID     41580 non-null  int64
#  1   Province_Name  41580 non-null  object
#  2   Year           41580 non-null  int64
#  3   DSL (Day)      41580 non-null  int64
#  4   R35mm (Day)    41580 non-null  int64
#  5   MONTH          41580 non-null  int64
#  6   MIN            41580 non-null  float64
#  7   MAX            41580 non-null  float64
#  8   MEAN           41580 non-null  float64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 3.2+ MB

# %%
df5
# Out:
#        ProvinceID Province_Name  Year  DSL (Day)  R35mm (Day)  MONTH  \
# 0              10       Bangkok  1979         22            6      1
# 1              10       Bangkok  1979         22            6      2
# 2              10       Bangkok  1979         22            6      3
# 3              10       Bangkok  1979         22            6      4
# 4              10       Bangkok  1979         22            6      5
# ...           ...           ...   ...        ...          ...    ...
# 41575          96    Narathiwat  2023          6           14      8
# 41576          96    Narathiwat  2023          6           14      9
# 41577          96    Narathiwat  2023          6           14     10
# 41578          96    Narathiwat  2023          6           14     11
# 41579          96    Narathiwat  2023          6           14     12
#
#              MIN          MAX        MEAN
# 0       0.000000    59.490002    5.510257
# 1       0.000000    82.089996   13.988614
# ...

# %%
# df5.to_csv('dataset_rain.csv', index=False)
# from google.colab import files
# files.download('dataset_rain.csv')

# %%
dataset_rain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41580 entries, 0 to 41579
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ProvinceID     41580 non-null  int64
#  1   Province_Name  41580 non-null  object
#  2   Year           41580 non-null  int64
#  3   DSL (Day)      41580 non-null  int64
#  4   R35mm (Day)    41580 non-null  int64
#  5   MONTH          41580 non-null  int64
#  6   MIN            41580 non-null  float64
#  7   MAX            41580 non-null  float64
#  8   MEAN           41580 non-null  float64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 2.9+ MB

# %%
print('duplicated: %s'%dataset_rain.duplicated().sum())
# Out:
# duplicated: 0

# %%
dataset_rain.isnull().sum(axis=0)
# Out:
# ProvinceID       0
# Province_Name    0
# Year             0
# DSL (Day)        0
# R35mm (Day)      0
# MONTH            0
# MIN              0
# MAX              0
# MEAN             0
# dtype: int64
